# %%
! pip install gensim
# Out:
# Requirement already satisfied: gensim in d:\anaconda\envs\ai\lib\site-packages (4.4.0)
# Requirement already satisfied: numpy>=1.18.5 in d:\anaconda\envs\ai\lib\site-packages (from gensim) (2.1.2)
# Requirement already satisfied: scipy>=1.7.0 in d:\anaconda\envs\ai\lib\site-packages (from gensim) (1.15.3)
# Requirement already satisfied: smart_open>=1.8.1 in d:\anaconda\envs\ai\lib\site-packages (from gensim) (7.5.0)
# Requirement already satisfied: wrapt in d:\anaconda\envs\ai\lib\site-packages (from smart_open>=1.8.1->gensim) (1.17.3)

# %%
import gensim.downloader as api
model=api.load("word2vec-google-news-300")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 2
#       1 import gensim.downloader as api
# ----> 2 model=api.load("word2vec-google-news-300")
#
# File d:\anaconda\envs\ai\lib\site-packages\gensim\downloader.py:503, in load(name, return_path)
#     501 sys.path.insert(0, BASE_DIR)
#     502 module = __import__(name)
# --> 503 return module.load_data()
#
# File ~/gensim-data\word2vec-google-news-300\__init__.py:8, in load_data()
#       6 def load_data():
#       7     path = os.path.join(base_dir, 'word2vec-google-news-300', "word2vec-google-news-300.gz")
# ----> 8     model = KeyedVectors.load_word2vec_format(path, binary=True)
#       9     return model
#
# File d:\anaconda\envs\ai\lib\site-packages\gensim\models\keyedvectors.py:1721, in KeyedVectors.load_word2vec_format(cls, fname, fvocab, binary, encoding, unicode_errors, limit, datatype, no_header)
#    1674 @classmethod
#    1675 def load_word2vec_format(
#    1676         cls, fname, fvocab=None, binary=False, encoding='utf8', unicode_errors='strict',
#    1677         limit=None, datatype=REAL, no_header=False,
#    1678     ):
#    1679     """Load KeyedVectors from a file produced by the original C word2vec-tool format.
#    1680
#    1681     Warnings
#    (...)
#    1719
#    1720     """
# -> 1721     return _load_word2vec_format(
#    1722         cls, fname, fvocab=fvocab, binary=binary, encoding=encoding, unicode_errors=unicode_errors,
#    1723         limit=limit, datatype=datatype, no_header=no_header,
#    1724     )
#
# File d:\anaconda\envs\ai\lib\site-packages\gensim\models\keyedvectors.py:2067, in _load_word2vec_format(cls, fname, fvocab, binary, encoding, unicode_errors, limit, datatype, no_header, binary_chunk_size)
#    2064 kv = cls(vector_size, vocab_size, dtype=datatype)
#    2066 if binary:
# -> 2067     _word2vec_read_binary(
#    2068         fin, kv, counts, vocab_size, vector_size, datatype, unicode_errors, binary_chunk_size, encoding
#    2069     )
#    2070 else:
#    2071     _word2vec_read_text(fin, kv, counts, vocab_size, vector_size, datatype, unicode_errors, encoding)
#
# File d:\anaconda\envs\ai\lib\site-packages\gensim\models\keyedvectors.py:1960, in _word2vec_read_binary(fin, kv, counts, vocab_size, vector_size, datatype, unicode_errors, binary_chunk_size, encoding)
#    1957 tot_processed_words = 0
#    1959 while tot_processed_words < vocab_size:
# -> 1960     new_chunk = fin.read(binary_chunk_size)
#    1961     chunk += new_chunk
#    1962     processed_words, chunk = _add_bytes_to_kv(
#    1963         kv, counts, chunk, vocab_size, vector_size, datatype, unicode_errors, encoding)
#
# File d:\anaconda\envs\ai\lib\gzip.py:301, in GzipFile.read(self, size)
#     299     import errno
#     300     raise OSError(errno.EBADF, "read() on write-only GzipFile object")
# --> 301 return self._buffer.read(size)
#
# File d:\anaconda\envs\ai\lib\_compression.py:68, in DecompressReader.readinto(self, b)
#      66 def readinto(self, b):
#      67     with memoryview(b) as view, view.cast("B") as byte_view:
# ---> 68         data = self.read(len(byte_view))
#      69         byte_view[:len(data)] = data
#      70     return len(data)
#
# File d:\anaconda\envs\ai\lib\gzip.py:496, in _GzipReader.read(self, size)
#     493 # Read a chunk of data from the file
#     494 buf = self._fp.read(io.DEFAULT_BUFFER_SIZE)
# --> 496 uncompress = self._decompressor.decompress(buf, size)
#     497 if self._decompressor.unconsumed_tail != b"":
#     498     self._fp.prepend(self._decompressor.unconsumed_tail)
#
# KeyboardInterrupt:

# %%
import torch
input_ids=torch.tensor([2,3,5,1])

# %%
vocab_size=6
output_dim=3

torch.manual_seed(123) #what this line does- it sets the seed for generating random numbers in PyTorch. By setting a specific seed value (in this case, 123), you ensure that the sequence of random numbers generated is reproducible. This is important for debugging and comparing results across different runs of your code, as it allows you to obtain the same random values each time you run the program.
embedding_layer=torch.nn.Embedding(vocab_size,output_dim)

# %%
print(embedding_layer.weight)
# Out:
# Parameter containing:
# tensor([[ 0.3374, -0.1778, -0.1690],
#         [ 0.9178,  1.5810,  1.3010],
#         [ 1.2753, -0.2010, -0.1606],
#         [-0.4015,  0.9666, -1.1481],
#         [-1.1589,  0.3255, -0.6315],
#         [-2.8400, -0.7849, -1.4096]], requires_grad=True)

# %%
print(embedding_layer(torch.tensor([3])))
# Out:
# tensor([[-0.4015,  0.9666, -1.1481]], grad_fn=<EmbeddingBackward0>)
